# %%
def test_one():
    a = 5
    b = 3
    assert a > b
    
test_one()

# %%
def test_two():
    a = [1,2,3,4,5]
    b = 3
    assert b in a
    
test_two()

# %%
def test_fail():
    assert False
    
test_fail()
