# %%
a = 4
b = 2

# %%
assert b*2 == 4

# %%
# This should always fail
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-b5f75a965503> in <module>()
#       1 # This should always fail
# ----> 2 assert False
#
# AssertionError:

# %%
print("We don't get to this cell in automated run")
